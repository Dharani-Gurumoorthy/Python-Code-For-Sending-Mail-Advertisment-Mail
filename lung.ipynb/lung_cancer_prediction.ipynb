# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharani-Gurumoorthy/Python-Code-For-Sending-Mail-Advertisment-Mail/blob/main/lung.ipynb/lung_cancer_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# !pip pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# ERROR: unknown command "pandas"

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/mohamedhanyyy/chest-ctscan-images")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: nithishkumar0227
# Your Kaggle Key: ··········
# Downloading chest-ctscan-images.zip to ./chest-ctscan-images
# 100%|██████████| 119M/119M [00:07<00:00, 17.7MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# File Directory for both the train and test
train_path = "/content/chest-ctscan-images/Data/train"
val_path = "/content/chest-ctscan-images/Data/valid"
test_path = "/content/chest-ctscan-images/Data/test"

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;

train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115}
#
#  {'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15, 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21}
#
#  {'normal': 54, 'large.cell.carcinoma': 51, 'adenocarcinoma': 120, 'squamous.cell.carcinoma': 90}

# %%
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.7.1

# %%
# !pip install matplotlib --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
labels = ['Squamous Cell Carcinoma', 'Normal', 'Adenocarcinoma', 'Large Cell Carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train',color = 'red')
rects2 = ax.bar(x, val_list, width, label='Val', color = 'blue')
rects3 = ax.bar(x + width, test_list, width, label='Test', color = 'green')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %% [markdown]
# <h2>
# Importing Keras for Image Classification

# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# <h2>Incep

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

base_model = InceptionV3(input_shape = (350, 350, 3),
                         include_top = False,
                         weights = 'imagenet')


for layer in base_model.layers:
    layer.trainable = False


x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Add a final sigmoid layer with 4 node for classification output
x = layers.Dense(4, activation='sigmoid')(x)

model_incep = tf.keras.models.Model(base_model.input, x)

model_incep.compile(optimizer = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001),
                    loss = 'categorical_crossentropy',
                    metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step

# %%
mc1 = ModelCheckpoint(
    filepath="./ct_incep_best_model.hdf5",
    monitor= 'val_accuracy',
    verbose= 1,
    save_best_only= True,
    mode = 'auto'
    );

call_back = [mc1];

# %%
# Fitting the Model
incep = model_incep.fit(
    train_data,
    steps_per_epoch = train_data.samples//train_data.batch_size,
    epochs = 32,
    validation_data = val_data,
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 5.4964 - accuracy: 0.4326
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 46s 261ms/step - loss: 5.4964 - accuracy: 0.4326 - val_loss: 3.1700 - val_accuracy: 0.5000
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 1.5916 - accuracy: 0.5691
# Epoch 2: val_accuracy improved from 0.50000 to 0.55714, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 30s 247ms/step - loss: 1.5916 - accuracy: 0.5691 - val_loss: 1.4644 - val_accuracy: 0.5571
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1596 - accuracy: 0.6086
# Epoch 3: val_accuracy did not improve from 0.55714
# 122/122 [==============================] - 21s 175ms/step - loss: 1.1596 - accuracy: 0.6086 - val_loss: 1.1066 - val_accuracy: 0.4857
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9852 - accuracy: 0.6316
# Epoch 4: val_accuracy improved from 0.55714 to 0.60000, saving model to ./ct_incep_best_model.hdf5
# 122/122 [==============================] - 30s 246ms/step - loss: 0.9852 - accuracy: 0.6316 - val_loss: 0.8963 - val_accuracy: 0.6000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-15fcf1838020> in <cell line: 2>()
#       1 # Fitting the Model
# ----> 2 incep = model_incep.fit(
#       3     train_data,
#       4     steps_per_epoch = train_data.samples//train_data.batch_size,
#       5     epochs = 32,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1671             logs = None
#    1672             for epoch, iterator in data_handler.enumerate_epochs():
# -> 1673                 self.reset_metrics()
#    1674                 callbacks.on_epoch_begin(epoch)
#    1675                 with data_handler.catch_stop_iteration():
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in reset_metrics(self)
#    2426         return tf_utils.sync_to_numpy_or_python_type(all_outputs)
#    2427
# -> 2428     def reset_metrics(self):
#    2429         """Resets the state of all the metrics in the model.
#    2430
#
# KeyboardInterrupt:

# %%
# Loading the Best Fit Model
model_incep = load_model("./ct_incep_best_model.hdf5")

# %% [markdown]
# Resnet 50 Model

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(input_shape=(350, 350,3),
                      include_top=False, weights="imagenet",
                      pooling='max')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
model_resnet = Sequential()
model_resnet.add(base_model)
model_resnet.add(Dense(4, activation='sigmoid'))

# %%
model_resnet.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001),
                     loss = 'categorical_crossentropy',
                     metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_resnet_best_model.hdf5",
    monitor= 'val_accuracy',
    verbose= 1,
    save_best_only= True,
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
resnet = model_resnet.fit(
    train_data,
    steps_per_epoch = train_data.samples//train_data.batch_size,
    epochs = 32,
    validation_data = val_data,
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 1.4879 - accuracy: 0.2869
# Epoch 1: val_accuracy improved from -inf to 0.47143, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 27s 175ms/step - loss: 1.4879 - accuracy: 0.2869 - val_loss: 1.3067 - val_accuracy: 0.4714
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 1.3032 - accuracy: 0.3651
# Epoch 2: val_accuracy did not improve from 0.47143
# 122/122 [==============================] - 22s 178ms/step - loss: 1.3032 - accuracy: 0.3651 - val_loss: 1.1886 - val_accuracy: 0.4000
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2214 - accuracy: 0.4145
# Epoch 3: val_accuracy did not improve from 0.47143
# 122/122 [==============================] - 20s 163ms/step - loss: 1.2214 - accuracy: 0.4145 - val_loss: 1.2372 - val_accuracy: 0.3714
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1483 - accuracy: 0.4507
# Epoch 4: val_accuracy did not improve from 0.47143
# 122/122 [==============================] - 23s 189ms/step - loss: 1.1483 - accuracy: 0.4507 - val_loss: 1.1273 - val_accuracy: 0.4571
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1125 - accuracy: 0.4786
# Epoch 5: val_accuracy did not improve from 0.47143
# 122/122 [==============================] - 21s 175ms/step - loss: 1.1125 - accuracy: 0.4786 - val_loss: 1.0807 - val_accuracy: 0.4286
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1354 - accuracy: 0.4293
# Epoch 6: val_accuracy did not improve from 0.47143
# 122/122 [==============================] - 21s 170ms/step - loss: 1.1354 - accuracy: 0.4293 - val_loss: 1.1513 - val_accuracy: 0.4000
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0994 - accuracy: 0.4868
# Epoch 7: val_accuracy improved from 0.47143 to 0.50000, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 21s 172ms/step - loss: 1.0994 - accuracy: 0.4868 - val_loss: 1.0554 - val_accuracy: 0.5000
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1034 - accuracy: 0.4655
# Epoch 8: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 20s 163ms/step - loss: 1.1034 - accuracy: 0.4655 - val_loss: 1.0645 - val_accuracy: 0.4857
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0791 - accuracy: 0.4836
# Epoch 9: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 22s 179ms/step - loss: 1.0791 - accuracy: 0.4836 - val_loss: 1.2671 - val_accuracy: 0.4000
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0761 - accuracy: 0.4720
# Epoch 10: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 21s 174ms/step - loss: 1.0761 - accuracy: 0.4720 - val_loss: 1.1006 - val_accuracy: 0.4857
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0762 - accuracy: 0.4819
# Epoch 11: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 21s 168ms/step - loss: 1.0762 - accuracy: 0.4819 - val_loss: 1.0597 - val_accuracy: 0.4857
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0514 - accuracy: 0.4754
# Epoch 12: val_accuracy did not improve from 0.50000
# 122/122 [==============================] - 21s 169ms/step - loss: 1.0514 - accuracy: 0.4754 - val_loss: 1.0277 - val_accuracy: 0.5000
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0711 - accuracy: 0.4737
# Epoch 13: val_accuracy improved from 0.50000 to 0.51429, saving model to ./ct_resnet_best_model.hdf5
# 122/122 [==============================] - 22s 177ms/step - loss: 1.0711 - accuracy: 0.4737 - val_loss: 1.0392 - val_accuracy: 0.5143
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0691 - accuracy: 0.4770
# Epoch 14: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 163ms/step - loss: 1.0691 - accuracy: 0.4770 - val_loss: 1.1850 - val_accuracy: 0.4571
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0580 - accuracy: 0.4638
# Epoch 15: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 176ms/step - loss: 1.0580 - accuracy: 0.4638 - val_loss: 1.0012 - val_accuracy: 0.4571
# Epoch 16/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0673 - accuracy: 0.4507
# Epoch 16: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 176ms/step - loss: 1.0673 - accuracy: 0.4507 - val_loss: 1.0324 - val_accuracy: 0.4143
# Epoch 17/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0412 - accuracy: 0.5115
# Epoch 17: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 167ms/step - loss: 1.0412 - accuracy: 0.5115 - val_loss: 1.0586 - val_accuracy: 0.4571
# Epoch 18/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0488 - accuracy: 0.4885
# Epoch 18: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 175ms/step - loss: 1.0488 - accuracy: 0.4885 - val_loss: 1.0134 - val_accuracy: 0.3571
# Epoch 19/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0492 - accuracy: 0.4951
# Epoch 19: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 164ms/step - loss: 1.0492 - accuracy: 0.4951 - val_loss: 0.9746 - val_accuracy: 0.4714
# Epoch 20/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0332 - accuracy: 0.5099
# Epoch 20: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 174ms/step - loss: 1.0332 - accuracy: 0.5099 - val_loss: 1.0119 - val_accuracy: 0.5000
# Epoch 21/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0269 - accuracy: 0.5099
# Epoch 21: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 179ms/step - loss: 1.0269 - accuracy: 0.5099 - val_loss: 1.0834 - val_accuracy: 0.4000
# Epoch 22/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0501 - accuracy: 0.4786
# Epoch 22: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 167ms/step - loss: 1.0501 - accuracy: 0.4786 - val_loss: 1.0056 - val_accuracy: 0.4857
# Epoch 23/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0507 - accuracy: 0.4770
# Epoch 23: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 170ms/step - loss: 1.0507 - accuracy: 0.4770 - val_loss: 1.1224 - val_accuracy: 0.3857
# Epoch 24/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0352 - accuracy: 0.4819
# Epoch 24: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 169ms/step - loss: 1.0352 - accuracy: 0.4819 - val_loss: 1.0159 - val_accuracy: 0.4571
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0434 - accuracy: 0.4737
# Epoch 25: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 169ms/step - loss: 1.0434 - accuracy: 0.4737 - val_loss: 1.0251 - val_accuracy: 0.3571
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0309 - accuracy: 0.4967
# Epoch 26: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 167ms/step - loss: 1.0309 - accuracy: 0.4967 - val_loss: 0.9934 - val_accuracy: 0.4571
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0246 - accuracy: 0.5066
# Epoch 27: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 169ms/step - loss: 1.0246 - accuracy: 0.5066 - val_loss: 1.0647 - val_accuracy: 0.4714
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0380 - accuracy: 0.4770
# Epoch 28: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 170ms/step - loss: 1.0380 - accuracy: 0.4770 - val_loss: 1.0030 - val_accuracy: 0.5000
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0136 - accuracy: 0.5132
# Epoch 29: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 21s 168ms/step - loss: 1.0136 - accuracy: 0.5132 - val_loss: 1.0928 - val_accuracy: 0.3714
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0172 - accuracy: 0.4803
# Epoch 30: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 163ms/step - loss: 1.0172 - accuracy: 0.4803 - val_loss: 1.0537 - val_accuracy: 0.4000
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0417 - accuracy: 0.5016
# Epoch 31: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 22s 180ms/step - loss: 1.0417 - accuracy: 0.5016 - val_loss: 1.1340 - val_accuracy: 0.3857
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0209 - accuracy: 0.5263
# Epoch 32: val_accuracy did not improve from 0.51429
# 122/122 [==============================] - 20s 163ms/step - loss: 1.0209 - accuracy: 0.5263 - val_loss: 1.2092 - val_accuracy: 0.4571

# %%
# Loading the Best Fit Model
model = load_model("./ct_resnet_best_model.hdf5")

# %%
test_score = model_incep.evaluate_generator(generator= test_data)
test_score_resnet = model.evaluate_generator(generator= test_data)

# %%
# Checking the Accuracy of the Model Resnet50
accuracy_resnet = model.evaluate_generator(generator= test_data)[1]
print(f"The accuracy of the model is = {accuracy_resnet*100} %")
loss_resnet = test_score[0]
print(f"The loss of the model is = {loss_resnet} %")
# Out:
# The accuracy of the model is = 54.92063760757446 %
# The loss of the model is = 0.6522243022918701 %

# %%
# Checking the Accuracy of the Incep
accuracy_incep = model_incep.evaluate_generator(generator= test_data)[1]
print(f"The accuracy of the model is = {accuracy_incep*100} %")
loss_incep = test_score[0]
print(f"The loss of the model is = {loss_incep} %")
# Out:
# The accuracy of the model is = 78.41269969940186 %
# The loss of the model is = 0.6522243022918701 %

# %%
incep.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Plot model performance
acc = incep.history['accuracy']
val_acc = incep.history['val_accuracy']
loss = incep.history['loss']
val_loss = incep.history['val_loss']
epochs_range = range(1, len(incep.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
algos = ['Resnet50','Incep']
accuracy = [accuracy_resnet, accuracy_incep]
accuracy = np.floor([i * 100 for i in accuracy])

fig = plt.figure(figsize = (2, 5))
#fig.set_figwidth(4)

# creating the bar plot
plt.bar(algos, accuracy, color ='blue', width = 0.1)

plt.xlabel("Algorithms Applied")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
            plt.tight_layout()
            plt.ylabel('True label')
            plt.xlabel('Predicted label')
#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools
#shuffle=False
target_names = []
for key in train_data.class_indices:
    target_names.append(key)
# print(target_names)
#Confution Matrix
Y_pred = model.predict_generator(test_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(test_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
#Print Classification Report
print('Classification Report')
print(classification_report(test_data.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#                                                   precision    recall  f1-score   support
#
#       adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib       0.38      0.82      0.52       120
#    large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa       0.00      0.00      0.00        51
#                                           normal       0.13      0.13      0.13        54
# squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa       0.00      0.00      0.00        90
#
#                                         accuracy                           0.34       315
#                                        macro avg       0.13      0.24      0.16       315
#                                     weighted avg       0.17      0.34      0.22       315

# %% [markdown]
# Predictions

# %%
def chestScanPrediction(path, _model):
    classes_dir = ["Adenocarcinoma","Large cell carcinoma","Normal","Squamous cell carcinoma"]
    # Loading Image
    img = image.load_img(path, target_size=(350,350))
    # Normalizing Image
    norm_img = image.img_to_array(img)/250
    # Converting Image to Numpy Array
    input_arr_img = np.array([norm_img])
    # Getting Predictions
    pred = np.argmax(_model.predict(input_arr_img))
    # Printing Model Prediction
    print(classes_dir[pred])

# %%
path = "/content/drive/MyDrive/DataSet/lung cancer data/Data/test/normal/10 - Copy (2) - Copy.png"
chestScanPrediction(path,model_incep)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Normal
